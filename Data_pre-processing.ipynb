# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd 
import matplotlib.pyplot as plt
import plotly.io as pio
pio.renderers.default='browser'
import pyarrow.feather as feather
import plotly.express as px
import numpy as np

# %%
density_data = pd.read_csv("Data/cluster_0_data.csv", low_memory=False) # Kevitsa
#enterprise_data = feather.read_feather("/Users/lin236/Documents/Data_Parker/Enterprise_pre2010_Desurvey.csv")

# %%
df = density_data.copy()
#df = enterprise_data.copy()

filtered_samples = df.dropna(subset=['Alt1_Code', 'Alt2_Code', 'Density_gcm3'])
#filtered_samples = df.dropna(subset=['Au_ppm', 'As_ppm_BESTEL', 'Hg_ppm_BESTEL'])


sample_count = len(filtered_samples)

print(f"Number of samples with alteration and Density_gcm3 data: {sample_count}")
#print(f"Number of samples with gold and pathfinder (As, Hg) data: {sample_count}")
# Out:
# Number of samples with alteration and Density_gcm3 data: 1346

# %%
# log transform the data
filtered_samples['Log_Au_ppm'] = np.log(filtered_samples['Au_ppm'])

# Create 3D scatter plot
fig = px.scatter_3d(filtered_samples, \
                    x='X', y='Y', z='Z', \
                        color='Log_Au_ppm', size='Au_ppm', \
                        opacity=0.7, labels={'Log_Au_ppm': 'Gold log(ppm)'})

fig.update_traces(marker=dict(line=dict(width=0)))
# Show plot
fig.show()
# Out:
# /var/folders/w4/w0jphlm16_q_7_x766w1p5rm0000gp/T/ipykernel_80306/647922284.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#mineral = 'Au_ppm'
mineral = 'Density_gcm3'
filter = ['Sulph1_Code', 'Sulph1_Pct', 'Sulph2_Code', 'Sulph2_Pct']
deposit_data = density_data

deposit_data = deposit_data.dropna(subset=[mineral] + filter)
deposit_data = filtered_samples
#df1 = deposit_data
df1 = filtered_samples
variable = mineral

# %%
two_composite_1covariates = deposit_data

missing_percentage = (two_composite_1covariates.isnull().sum() / len(two_composite_1covariates)) * 100

variables_to_remove = missing_percentage[missing_percentage > 5].index

two_composite_1covariates = two_composite_1covariates.drop(columns=variables_to_remove)


encoded_data = two_composite_1covariates.copy()

threshold = 10

for column in two_composite_1covariates.columns:
    if two_composite_1covariates[column].dtype == 'object':
        unique_values = two_composite_1covariates[column].nunique()
        
        if unique_values <= threshold:
            encoded_columns = pd.get_dummies(encoded_data[column], prefix=column)
            encoded_columns = encoded_columns.astype(int)  
            encoded_data = pd.concat([encoded_data, encoded_columns], axis=1)
            encoded_data = encoded_data.drop(columns=[column])




encoded_columns = [col for col in encoded_data.columns if '_Code_' in col]

total_columns = []

for col in encoded_columns:
    prefix, original_column = col.split('_Code_')
    
    total_column = f"{original_column}_Total"
    total_columns.append(total_column)
    
    encoded_data[total_column] = (
        encoded_data[f"{prefix}_Code_{original_column}"] * encoded_data[f"{prefix}_Pct"]
    )

total_columns = []

category_totals = {}

for col in encoded_columns:
    prefix, original_column = col.split('_Code_')
    
    total_column = f"{original_column}_Total"
    if total_column not in total_columns:
        total_columns.append(total_column)
    
    total_values = encoded_data[f"{prefix}_Code_{original_column}"] * encoded_data[f"{prefix}_Pct"]
    
    if total_column in category_totals:
        category_totals[total_column] += total_values
    else:
        category_totals[total_column] = total_values

for total_column, total_values in category_totals.items():
    encoded_data[total_column] = total_values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\lin236\Anaconda3\envs\Loop\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\lin236\Anaconda3\envs\Loop\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\lin236\Anaconda3\envs\Loop\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Alt1_Pct'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 38
#      34     total_column = f"{original_column}_Total"
#      35     total_columns.append(total_column)
#      37     encoded_data[total_column] = (
# ---> 38         encoded_data[f"{prefix}_Code_{original_column}"] * encoded_data[f"{prefix}_Pct"]
#      39     )
#      41 total_columns = []
#      43 category_totals = {}
#
# File c:\Users\lin236\Anaconda3\envs\Loop\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File c:\Users\lin236\Anaconda3\envs\Loop\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Alt1_Pct'

# %%
variable_names = ['Sc_ppm',
 'Al_pct',
 'Y_ppm',
 'V_ppm',
 'Sr_ppm',
 'Ca_pct',
 'P_ppm',
 'Si_pct',
 'Li_ppm',
 'Mg_pct',
 'La_ppm',
 'RQD_Pct',
 'Alt1_Int_wk',
 'Ba_ppm',
 'Sulph1_Code_PO',
 'IP_pct',
 'Sulph2_Code_CP',
 'Sulph2_Code_PO',
 'X',
 'PY_Total',
 'Z',
 'PO_Total',
 'CP_Total',
 'Cr_ppm',
 'B_ppm',
 'Y',
 'Sb_ppm',
 'Weathering']

# %%
filtered_encoded_data = encoded_data[encoded_data.columns.intersection(variable_names+ ['Density_gcm3', 'Name'])]

deposit_data = encoded_data[['Name', 'X', 'Y', 'Z', 'Density_gcm3', 'RQD_Pct', 'Cr_ppm', 'CP_Total',
       'PO_Total', 'PY_Total']]
total_columns = ['CP_Total','PO_Total', 'PY_Total']


deposit_data.describe()
deposit_data.fillna(0, inplace=True)
deposit_data
# Out:
# /var/folders/w4/w0jphlm16_q_7_x766w1p5rm0000gp/T/ipykernel_24277/1682930821.py:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             Name           X           Y       Z  Density_gcm3  RQD_Pct  \
# 393    KV-NME001  3498922.13  7511747.51  148.80          3.13    88.00
# 394    KV-NME001  3498922.68  7511747.45  146.88          3.15    88.00
# 434    KV-NME001  3498945.16  7511745.25   70.14          3.22    99.00
# 435    KV-NME001  3498945.73  7511745.20   68.22          3.22    99.00
# 436    KV-NME001  3498946.29  7511745.15   66.30          3.22    99.00
# ...          ...         ...         ...     ...           ...      ...
# 81071      KV365  3499347.52  7510618.17   85.03          3.44    92.35
# 81072      KV365  3499347.32  7510617.19   83.30          3.43    92.35
# 81073      KV365  3499347.13  7510616.22   81.56          3.44    85.84
# 81074      KV365  3499346.93  7510615.24   79.83          3.40    85.84
# 81075      KV365  3499346.74  7510614.27   78.09          3.41    85.84
#
#        Cr_ppm  CP_Total  PO_Total  PY_Total
# 393     212.6       1.0       1.0       0.0
# 394     268.0       1.0       1.0       0.0
# 434     215.0       1.0       1.0       0.0
# 435     236.0       1.5       2.0       0.0
# 436     256.0       2.0       3.0       0.0
# ...       ...       ...       ...       ...
# 81071   131.0       0.2       3.0       0.0
# 81072   125.0       0.2       3.0       0.0
# 81073   128.0       0.2       3.0       0.0
# 81074   129.0       0.2       3.0       0.0
# 81075   130.0       0.2       3.0       0.0
#
# [2618 rows x 10 columns]

# %%
variables = ['X', 'Y', 'Z', 'PY_Total', 'PO_Total', 'CP_Total', 'Cr_ppm', 'RQD_Pct', 'Density_gcm3']

variables2 = ['X (m)', 'Y (m)', 'Z (m)', 'Pyrite (%)', 'Pyrrhotite (%)', 'Chalcopyrite (%)', 'Chromium (ppm)', 'Rock-quality designation (%)', 'Density (g/cm3)']
fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(15, 12))

for i, var in enumerate(variables):
    row = i // 3
    col = i % 3
    axs[row, col].hist(deposit_data[var], bins=20, color='#C26DBC', edgecolor='black')
    axs[row, col].set_xlabel(str(variables2[i]))
    axs[row, col].set_ylabel('Frequency')
    axs[row, col].grid(False)
    if var == 'X':
        x_ticks = axs[row, col].get_xticks()
        x_ticks = x_ticks[::1]  
        axs[row, col].set_xticks(x_ticks)

plt.tight_layout()
plt.show()

# %%
deposit_data['Log_Au_ppm'] = np.log(deposit_data['Au_ppm'])
deposit_data['Log_As_ppm_BESTEL'] = np.log(deposit_data['As_ppm_BESTEL'])
deposit_data['Log_Hg_ppm_BESTEL'] = np.log(deposit_data['Hg_ppm_BESTEL'])
columns = ['X', 'Y', 'Z', 'Log_Au_ppm', 'Log_As_ppm_BESTEL', 'Log_Hg_ppm_BESTEL']
scatter_matrix = pd.plotting.scatter_matrix(deposit_data[columns], figsize=(30, 30))

#import seaborn as sns

# columns = ['X', 'Y', 'Z', 'CP_Total', 'PO_Total', 'PY_Total', 'RQD_Pct', 'Cr_ppm', 'Density_gcm3']
# sns.pairplot(deposit_data[columns], diag_kind='kde', corner=True)
# Out:
# /var/folders/w4/w0jphlm16_q_7_x766w1p5rm0000gp/T/ipykernel_80306/1565354413.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/w4/w0jphlm16_q_7_x766w1p5rm0000gp/T/ipykernel_80306/1565354413.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/lin236/Environments/Loop/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning:
#
# divide by zero encountered in log
#
# /var/folders/w4/w0jphlm16_q_7_x766w1p5rm0000gp/T/ipykernel_80306/1565354413.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 5
#       3 deposit_data['Log_Hg_ppm_BESTEL'] = np.log(deposit_data['Hg_ppm_BESTEL'])
#       4 columns = ['X', 'Y', 'Z', 'Log_Au_ppm', 'Log_As_ppm_BESTEL', 'Log_Hg_ppm_BESTEL']
# ----> 5 scatter_matrix = pd.plotting.scatter_matrix(deposit_data[columns], figsize=(30, 30))
#       7 #import seaborn as sns
#       8
#       9 # columns = ['X', 'Y', 'Z', 'CP_Total', 'PO_Total', 'PY_Total', 'RQD_Pct', 'Cr_ppm', 'Density_gcm3']
#      10 # sns.pairplot(deposit_data[columns], diag_kind='kde', corner=True)
#
# File ~/Environments/Loop/lib/python3.12/site-packages/pandas/plotting/_misc.py:220, in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwargs)
#     168 """
#     169 Draw a matrix of scatter plots.
#     170
#    (...)
#     217           dtype=object)
#     218 """
#     219 plot_backend = _get_plot_backend("matplotlib")
# --> 220 return plot_backend.scatter_matrix(
#     221     frame=frame,
#     222     alpha=alpha,
#     223     figsize=figsize,
#     224     ax=ax,
#     225     grid=grid,
#     226     diagonal=diagonal,
#     227     marker=marker,
#     228     density_kwds=density_kwds,
#     229     hist_kwds=hist_kwds,
#     230     range_padding=range_padding,
#     231     **kwargs,
#     232 )
#
# File ~/Environments/Loop/lib/python3.12/site-packages/pandas/plotting/_matplotlib/misc.py:100, in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwds)
#      94     common = (mask[a] & mask[b]).values
#      96     ax.scatter(
#      97         df[b][common], df[a][common], marker=marker, alpha=alpha, **kwds
#      98     )
# --> 100     ax.set_xlim(boundaries_list[j])
#     101     ax.set_ylim(boundaries_list[i])
#     103 ax.set_xlabel(b)
#
# File ~/Environments/Loop/lib/python3.12/site-packages/matplotlib/axes/_base.py:3745, in _AxesBase.set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3743         raise TypeError("Cannot pass both 'right' and 'xmax'")
#    3744     right = xmax
# -> 3745 return self.xaxis._set_lim(left, right, emit=emit, auto=auto)
#
# File ~/Environments/Loop/lib/python3.12/site-packages/matplotlib/axis.py:1235, in Axis._set_lim(self, v0, v1, emit, auto)
#    1232 name = self._get_axis_name()
#    1234 self.axes._process_unit_info([(name, (v0, v1))], convert=False)
# -> 1235 v0 = self.axes._validate_converted_limits(v0, self.convert_units)
#    1236 v1 = self.axes._validate_converted_limits(v1, self.convert_units)
#    1238 if v0 is None or v1 is None:
#    1239     # Axes init calls set_xlim(0, 1) before get_xlim() can be called,
#    1240     # so only grab the limits if we really need them.
#
# File ~/Environments/Loop/lib/python3.12/site-packages/matplotlib/axes/_base.py:3666, in _AxesBase._validate_converted_limits(self, limit, convert)
#    3663     converted_limit = converted_limit.squeeze()
#    3664 if (isinstance(converted_limit, Real)
#    3665         and not np.isfinite(converted_limit)):
# -> 3666     raise ValueError("Axis limits cannot be NaN or Inf")
#    3667 return converted_limit
#
# ValueError: Axis limits cannot be NaN or Inf

# %%
summary = deposit_data.describe().round(3)

latex_table = summary.to_latex()
# Out:
# /Users/lin236/Environments/Loop/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning:
#
# invalid value encountered in subtract

# %%
#deposit_data.to_csv('Data/filtered_unnormalised_deposit_data.csv', index=False)

# %%
columns_to_normalize = ['X', 'Y', 'Z']   

min_values = deposit_data[columns_to_normalize].min()

for column in columns_to_normalize:
    deposit_data[column] = deposit_data[column] - min_values[column]

# Calculate the minimum and maximum values from all three variables
min_values = deposit_data[columns_to_normalize].min().min()
max_values = deposit_data[columns_to_normalize].max().max()

for column in columns_to_normalize:
    deposit_data[column] = (deposit_data[column] - min_values) / (max_values - min_values)

#Scale the rest of the covariates in their own scale
covariates = ['As_ppm_BESTEL', 'Hg_ppm_BESTEL']
scaler = MinMaxScaler()
deposit_data.loc[:, [mineral] +covariates] = scaler.fit_transform(deposit_data.loc[:,[mineral] + covariates])
# Out:
# /var/folders/w4/w0jphlm16_q_7_x766w1p5rm0000gp/T/ipykernel_80306/1552991781.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/w4/w0jphlm16_q_7_x766w1p5rm0000gp/T/ipykernel_80306/1552991781.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
all_indexes = deposit_data.index
all_indexes.to_series().to_csv('/Users/lin236/Documents/Data_Parker/indexes.csv', index=False)

# %%
deposit_data.to_csv('/Users/lin236/Documents/Data_Parker/filtered_deposit_data.csv', index=False)
